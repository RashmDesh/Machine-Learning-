# %%
import pandas as pd
movies=pd.read_csv('C:/Users/lenovo/Desktop/datasets/movies.csv',sep=',')
print(type(movies))
movies.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
import pandas as pd
tags=pd.read_csv('C:/Users/lenovo/Desktop/datasets/tags.csv',sep=',')
print(type(tags))
tags.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
import pandas as pd
rate=pd.read_csv('C:/Users/lenovo/Desktop/datasets/ratings.csv',sep=',')
print(type(rate))
rate.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %% [markdown]
# # Filters for selecting row

# %%
is_highly_rated=rate['rating']>=4.0
rate[is_highly_rated][-5:]
# Out:
#           userId  movieId  rating   timestamp
# 25000088  162541    41566     4.0  1240952749
# 25000089  162541    45517     4.5  1240953353
# 25000090  162541    50872     4.5  1240953372
# 25000093  162541    58559     4.0  1240953434
# 25000094  162541    63876     5.0  1240952515

# %%
is_animation= movies['genres'].str.contains('Animation')
movies[is_animation][5:15]
# Out:
#      movieId                                       title  \
# 309      313                   Swan Princess, The (1994)
# 359      364                       Lion King, The (1994)
# 387      392  Secret Adventures of Tom Thumb, The (1993)
# 545      551      Nightmare Before Christmas, The (1993)
# 551      558                      Pagemaster, The (1994)
# 580      588                              Aladdin (1992)
# 586      594      Snow White and the Seven Dwarfs (1937)
# 587      595                 Beauty and the Beast (1991)
# 588      596                            Pinocchio (1940)
# 602      610                          Heavy Metal (1981)
#
#                                               genres
# 309                               Animation|Children
# 359  Adventure|Animation|Children|Drama|Musical|IMAX
# 387                              Adventure|Animation
# 545               Animation|Children|Fantasy|Musical
# 551      Action|Adventure|Animation|Children|Fantasy
# ...

# %%
movies[is_animation].head(5)
# Out:
#      movieId                    title  \
# 0          1         Toy Story (1995)
# 12        13             Balto (1995)
# 47        48        Pocahontas (1995)
# 236      239    Goofy Movie, A (1995)
# 241      244  Gumby: The Movie (1995)
#
#                                           genres
# 0    Adventure|Animation|Children|Comedy|Fantasy
# 12                  Adventure|Animation|Children
# 47      Animation|Children|Drama|Musical|Romance
# 236            Animation|Children|Comedy|Romance
# 241                           Animation|Children

# %% [markdown]
# # GROUP BY AGGRIGATION

# %%
ratings_count= rate[['movieId','rating']].groupby('rating').count()
ratings_count
# Out:
#         movieId
# rating
# 0.5      393068
# 1.0      776815
# 1.5      399490
# 2.0     1640868
# 2.5     1262797
# 3.0     4896928
# 3.5     3177318
# 4.0     6639798
# 4.5     2200539
# 5.0     3612474

# %%
ratings_avg= rate[['movieId','rating']].groupby('movieId').mean()
ratings_avg.tail()
# Out:
#          rating
# movieId
# 209157      1.5
# 209159      3.0
# 209163      4.5
# 209169      3.0
# 209171      3.0

# %%
movie_count= rate[['movieId','rating']].groupby('movieId').count()
movie_count.head()
# Out:
#          rating
# movieId
# 1         57309
# 2         24228
# 3         11804
# 4          2523
# 5         11714

# %%
movie_count= rate[['movieId','rating']].groupby('movieId').count()
movie_count.tail()
# Out:
#          rating
# movieId
# 209157        1
# 209159        1
# 209163        1
# 209169        1
# 209171        1

# %%
tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
movies.head
# Out:
# <bound method NDFrame.head of        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %%
t=movies.merge(tags,on='movieId',how='inner')
t.head(10)
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 5        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 6        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 7        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 8        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 9        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId           tag   timestamp
# 0     791         Owned  1515175493
# 1    1048  imdb top 250  1172144394
# 2    1361         Pixar  1216146311
# ...

# %%
t.shape
# Out:
# (1093360, 6)

# %%
t=movies.merge(tags,on='movieId',how='outer')
t.head(10)
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 5        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 6        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 7        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 8        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 9        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId           tag     timestamp
# 0   791.0         Owned  1.515175e+09
# 1  1048.0  imdb top 250  1.172144e+09
# ...

# %%
t.shape
# Out:
# (1110532, 6)

# %%
print('\U0001F923')
# Out:
# 🤣

# %%
avg_rating=rate.groupby('movieId',as_index=False).mean()
del avg_rating['userId']
avg_rating.head()
# Out:
#    movieId    rating     timestamp
# 0        1  3.893708  1.153152e+09
# 1        2  3.251527  1.122310e+09
# 2        3  3.142028  9.806023e+08
# 3        4  2.853547  9.424605e+08
# 4        5  3.058434  1.004723e+09

# %%
box_off=movies.merge(avg_rating,on='movieId',how='inner')
box_off.tail()
# Out:
#        movieId                           title                  genres  \
# 59042   209157                       We (2018)                   Drama
# 59043   209159       Window of the Soul (2001)             Documentary
# 59044   209163                Bad Poems (2018)            Comedy|Drama
# 59045   209169             A Girl Thing (2001)      (no genres listed)
# 59046   209171  Women of Devil's Island (1962)  Action|Adventure|Drama
#
#        rating     timestamp
# 59042     1.5  1.574281e+09
# 59043     3.0  1.574281e+09
# 59044     4.5  1.574285e+09
# 59045     3.0  1.574292e+09
# 59046     3.0  1.574292e+09

# %%
is_highly_rate=box_off['rating']>=4.0
box_off[is_highly_rate][-5:]
# Out:
#        movieId                                              title  \
# 59027   209121        Adrenalin: The BMW Touring Car Story (2014)
# 59028   209123  Square Roots: The Story of SpongeBob SquarePan...
# 59029   209129                           Destination Titan (2011)
# 59041   209155                         Santosh Subramaniam (2008)
# 59044   209163                                   Bad Poems (2018)
#
#                       genres  rating     timestamp
# 59027            Documentary     4.0  1.574143e+09
# 59028            Documentary     4.0  1.574174e+09
# 59029            Documentary     4.5  1.574184e+09
# 59041  Action|Comedy|Romance     5.0  1.574272e+09
# 59044           Comedy|Drama     4.5  1.574285e+09

# %%
is_comedy=box_off['genres'].str.contains('Comedy')

# %%
box_off[is_comedy & is_highly_rate][-5:]

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_geners=movies['genres'].str.split('|',expand=True)
movies_geners[:10]
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
# 5     Action      Crime  Thriller    None     None  None  None  None  None
# 6     Comedy    Romance      None    None     None  None  None  None  None
# 7  Adventure   Children      None    None     None  None  None  None  None
# 8     Action       None      None    None     None  None  None  None  None
# 9     Action  Adventure  Thriller    None     None  None  None  None  None
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# 5  None
# 6  None
# 7  None
# 8  None
# 9  None

# %%
movies_geners['is_comedy']=movies['genres'].str.contains('Comedy')
movies_geners[:10]
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
# 5     Action      Crime  Thriller    None     None  None  None  None  None
# 6     Comedy    Romance      None    None     None  None  None  None  None
# 7  Adventure   Children      None    None     None  None  None  None  None
# 8     Action       None      None    None     None  None  None  None  None
# 9     Action  Adventure  Thriller    None     None  None  None  None  None
#
#       9  is_comedy
# 0  None       True
# 1  None      False
# 2  None       True
# 3  None       True
# 4  None       True
# 5  None      False
# ...

# %%
movies['year']=movies['title'].str.extract('.*\((.*)\).*',expand=True)
movies.head(5)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %%
tags.dtypes
# Out:
# userId        int64
# movieId       int64
# tag          object
# timestamp     int64
# dtype: object

# %%
tags.head(5)
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
tags['p_time']=pd.to_datetime(tags['timestamp'],unit='s')
tags['p_time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
tags.head()
# Out:
#    userId  movieId               tag   timestamp              p_time
# 0       3      260           classic  1439472355 2015-08-13 13:25:55
# 1       3      260            sci-fi  1439472256 2015-08-13 13:24:16
# 2       4     1732       dark comedy  1573943598 2019-11-16 22:33:18
# 3       4     1732    great dialogue  1573943604 2019-11-16 22:33:24
# 4       4     7569  so bad it's good  1573943455 2019-11-16 22:30:55

# %%
ratings_avg= rate[['movieId','rating']].groupby('movieId',as_index=False).mean()
ratings_avg.tail()
# Out:
#        movieId  rating
# 59042   209157     1.5
# 59043   209159     3.0
# 59044   209163     4.5
# 59045   209169     3.0
# 59046   209171     3.0
