# %%
pip install tweepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install textblob
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install twitter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#import twitter

# %%
#from twitter import Twitter

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import itertools
import collections

import tweepy as tw
import nltk
from nltk.corpus import stopwords
import re
import networkx
from textblob import TextBlob

import warnings
warnings.filterwarnings("ignore")

# %%
consumer_key='u4Ptg4llSCUFbWxQ9T1nm9COW'
consumer_secret='Fdm4hiRWhN6XFJvCaSwhDh00lGepNyyokWB98bVGUloTX3BPey'
access_token='1394282767567839234-hxWDd6UZnJVU9rQlyZR4UmCV6Pd07g'
access_token_secret='ZtozeoqnmvCBJUgQE6Yp62TgCccZR1QxuyKeJ1ou9zVgT'

# %%
auth=tw.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api=tw.API(auth,wait_on_rate_limit=True)
api.update_status('Test')
# Out:
# Status(_api=<tweepy.api.API object at 0x000000000CDEE9A0>, _json={'created_at': 'Fri May 21 05:49:33 +0000 2021', 'id': 1395617742795919360, 'id_str': '1395617742795919360', 'text': 'Test', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">data_sci_demo</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1394282767567839234, 'id_str': '1394282767567839234', 'name': 'RASHMI DESHMUKH', 'screen_name': 'RASHMID63598806', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Mon May 17 13:26:07 +0000 2021', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled
# ...

# %%
def remove_url(txt):
    return " ".join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", txt).split())

# %%
search_term="#DataScience"
date_since='2018-11-01'

tweets=tw.Cursor(api.search,q=search_term,lang="en",since=date_since).items(1000)

tweet_no_urls=[remove_url(tweet.text) for tweet in tweets]
tweet_no_urls
# Out:
# ['RT IainLJBrown Students Create Owl Assist Chatbot Using Artificial Intelligence Keene State CollegeRead more here',
#  'The 5 Characteristics of a Great Data Scientist Exceptional data scientists share several key features which a',
#  'RT IainLJBrown Students Create Owl Assist Chatbot Using Artificial Intelligence Keene State CollegeRead more here',
#  'RT IainLJBrown Researchers use AI to detect wrist fractures ArtificialIntelligence AI DataScience 100DaysOfCode Python MachineLearn',
#  'RT SuzanneC0leman Stop Calling Everything AI MachineLearning Pioneer Says IEEE SpectrumRead more here Ar',
#  'RT BenjaminP3ters Lantern Pharma and Actuate Therapeutics Announce Research amp Development Collaboration Leveraging Lanterns Artificial I',
#  'RT BenjaminP3ters Lantern Pharma and Actuate Therapeutics Announce Research amp Development Collaboration Leveraging Lanterns Artificial I',
# ...

# %%
tweets=tw.Cursor(api.search,q=search_term,lang="en",since=date_since).items(1000)
users_locs=[[tweet.user.screen_name,tweet.user.location,tweet_no_urls] for tweet in tweets]
users_locs

# %%
tweet_text=pd.DataFrame(data=users_locs,columns=['user','location','tweets'])
tweet_text

# %%
tweet_text.tail(19)
